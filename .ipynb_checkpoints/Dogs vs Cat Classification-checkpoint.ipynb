# %%
import os
import zipfile
import random
from shutil import copyfile

# %%
pip install --upgrade tensorflow==2.0.0a0
# Out:
# Collecting tensorflow==2.0.0a0
#   Using cached https://files.pythonhosted.org/packages/29/39/f99185d39131b8333afcfe1dcdb0629c2ffc4ecfb0e4c14ca210d620e56c/tensorflow-2.0.0a0-cp36-cp36m-manylinux1_x86_64.whl
# Collecting gast>=0.2.0 (from tensorflow==2.0.0a0)
#   Using cached https://files.pythonhosted.org/packages/d6/84/759f5dd23fec8ba71952d97bcc7e2c9d7d63bdc582421f3cd4be845f0c98/gast-0.3.3-py2.py3-none-any.whl
# Collecting astor>=0.6.0 (from tensorflow==2.0.0a0)
#   Using cached https://files.pythonhosted.org/packages/c3/88/97eef84f48fa04fbd6750e62dcceafba6c63c81b7ac1420856c8dcc0a3f9/astor-0.8.1-py2.py3-none-any.whl
# Collecting keras-preprocessing>=1.0.5 (from tensorflow==2.0.0a0)
#   Downloading https://files.pythonhosted.org/packages/79/4c/7c3275a01e12ef9368a892926ab932b33bb13d55794881e3573482b378a7/Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42kB)
#     100% |████████████████████████████████| 51kB 182kB/s ta 0:00:01
# Collecting numpy<2.0,>=1.14.5 (from tensorflow==2.0.0a0)
#   Downloading https://files.pythonhosted.org/packages/00/16/476826a84d545424084499763248abbbdc73d065168efed9aa71cdf2a7dc/numpy-1.19.0-cp36-cp36m-manylinux1_x86_64.whl (13.5MB)
#     100% |████████████████████████████████| 13.5MB 17kB/s ta 0:00:012
# Collecting termcolor>=1.1.0 (from tensorflow==2.0.0a0)
# Collecting absl-py>=0.7.0 (from tensorflow==2.0.0a0)
# Collecting six>=1.10.0 (from tensorflow==2.0.0a0)
#   Downloading https://files.pythonhosted.org/packages/ee/ff/48bde5c0f013094d729fe4b0316ba2a24774b3ff1c52d924a8a4cb04078a/six-1.15.0-py2.py3-none-any.whl
# Collecting wheel>=0.26 (from tensorflow==2.0.0a0)
#   Using cached https://files.pythonhosted.org/packages/8c/23/848298cccf8e40f5bbb59009b32848a4c38f4e7f3364297ab3c3e2e2cd14/wheel-0.34.2-py2.py3-none-any.whl
# Collecting google-pasta>=0.1.2 (from tensorflow==2.0.0a0)
#   Using cached https://files.pythonhosted.org/packages/a3/de/c648ef6835192e6e2cc03f40b19eeda4382c49b5bafb43d88b931c4c74ac/google_pasta-0.2.0-py3-none-any.whl
# Collecting tf-estimator-nightly<1.14.0.dev2019030116,>=1.14.0.dev2019030115 (from tensorflow==2.0.0a0)
#   Using cached https://files.pythonhosted.org/packages/13/82/f16063b4eed210dc2ab057930ac1da4fbe1e91b7b051a6c8370b401e6ae7/tf_estimator_nightly-1.14.0.dev2019030115-py2.py3-none-any.whl
# Collecting protobuf>=3.6.1 (from tensorflow==2.0.0a0)
#   Downloading https://files.pythonhosted.org/packages/28/05/9867ef8eafd12265267bee138fa2c46ebf34a276ea4cbe184cba4c606e8b/protobuf-3.12.2-cp36-cp36m-manylinux1_x86_64.whl (1.3MB)
#     100% |████████████████████████████████| 1.3MB 175kB/s ta 0:00:01
# Collecting tb-nightly<1.14.0a20190302,>=1.14.0a20190301 (from tensorflow==2.0.0a0)
#   Using cached https://files.pythonhosted.org/packages/a9/51/aa1d756644bf4624c03844115e4ac4058eff77acd786b26315f051a4b195/tb_nightly-1.14.0a20190301-py3-none-any.whl
# Collecting keras-applications>=1.0.6 (from tensorflow==2.0.0a0)
#   Using cached https://files.pythonhosted.org/packages/71/e3/19762fdfc62877ae9102edf6342d71b28fbfd9dea3d2f96a882ce099b03f/Keras_Applications-1.0.8-py3-none-any.whl
# Collecting grpcio>=1.8.6 (from tensorflow==2.0.0a0)
#   Downloading https://files.pythonhosted.org/packages/5e/29/1bd649737e427a6bb850174293b4f2b72ab80dd49462142db9b81e1e5c7b/grpcio-1.30.0.tar.gz (19.7MB)
#     100% |████████████████████████████████| 19.7MB 56kB/s eta 0:00:01   40% |█████████████                   | 8.0MB 209kB/s eta 0:00:56
# Collecting setuptools (from protobuf>=3.6.1->tensorflow==2.0.0a0)
#   Downloading https://files.pythonhosted.org/packages/bd/a3/dfa1fe840aac5ea628155ca2341416c397496ece599b633658773295d7f0/setuptools-49.1.2-py3-none-any.whl (789kB)
#     100% |████████████████████████████████| 798kB 319kB/s ta 0:00:01
# Collecting markdown>=2.6.8 (from tb-nightly<1.14.0a20190302,>=1.14.0a20190301->tensorflow==2.0.0a0)
#   Downloading https://files.pythonhosted.org/packages/a4/63/eaec2bd025ab48c754b55e8819af0f6a69e2b1e187611dd40cbbe101ee7f/Markdown-3.2.2-py3-none-any.whl (88kB)
#     100% |████████████████████████████████| 92kB 290kB/s ta 0:00:01
# Collecting werkzeug>=0.11.15 (from tb-nightly<1.14.0a20190302,>=1.14.0a20190301->tensorflow==2.0.0a0)
#   Using cached https://files.pythonhosted.org/packages/cc/94/5f7079a0e00bd6863ef8f1da638721e9da21e5bacee597595b318f71d62e/Werkzeug-1.0.1-py2.py3-none-any.whl
# Collecting h5py (from keras-applications>=1.0.6->tensorflow==2.0.0a0)
#   Using cached https://files.pythonhosted.org/packages/60/06/cafdd44889200e5438b897388f3075b52a8ef01f28a17366d91de0fa2d05/h5py-2.10.0-cp36-cp36m-manylinux1_x86_64.whl
# Collecting importlib-metadata; python_version < "3.8" (from markdown>=2.6.8->tb-nightly<1.14.0a20190302,>=1.14.0a20190301->tensorflow==2.0.0a0)
#   Downloading https://files.pythonhosted.org/packages/8e/58/cdea07eb51fc2b906db0968a94700866fc46249bdc75cac23f9d13168929/importlib_metadata-1.7.0-py2.py3-none-any.whl
# Collecting zipp>=0.5 (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tb-nightly<1.14.0a20190302,>=1.14.0a20190301->tensorflow==2.0.0a0)
#   Downloading https://files.pythonhosted.org/packages/b2/34/bfcb43cc0ba81f527bc4f40ef41ba2ff4080e047acb0586b56b3d017ace4/zipp-3.1.0-py3-none-any.whl
# Building wheels for collected packages: grpcio
#   Running setup.py bdist_wheel for grpcio ... done
#   Stored in directory: /home/shoaibpc/.cache/pip/wheels/1e/e9/13/2ce6c99171a977bad2f9a4bccfa596a6e7ea060b9fbff51bc3
# Successfully built grpcio
# Installing collected packages: gast, astor, numpy, six, keras-preprocessing, termcolor, absl-py, wheel, google-pasta, tf-estimator-nightly, setuptools, protobuf, zipp, importlib-metadata, markdown, grpcio, werkzeug, tb-nightly, h5py, keras-applications, tensorflow
# Successfully installed absl-py-0.9.0 astor-0.8.1 gast-0.3.3 google-pasta-0.2.0 grpcio-1.30.0 h5py-2.10.0 importlib-metadata-1.7.0 keras-applications-1.0.8 keras-preprocessing-1.1.2 markdown-3.2.2 numpy-1.19.0 protobuf-3.12.2 setuptools-49.1.2 six-1.15.0 tb-nightly-1.14.0a20190301 tensorflow-2.0.0a0 termcolor-1.1.0 tf-estimator-nightly-1.14.0.dev2019030115 werkzeug-1.0.1 wheel-0.34.2 zipp-3.1.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import tensorflow as tf

# %%
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
local_zip = './dogs-vs-cats.zip'
zip_ref = zipfile.ZipFile(local_zip, 'r')
zip_ref.extractall('.')
zip_ref.close()

# %%
with zipfile.ZipFile("./train.zip","r") as z:
    z.extractall(".")
    
with zipfile.ZipFile("./test1.zip","r") as z:
    z.extractall(".")

# %%
import numpy as np
import pandas as pd 

filenames = os.listdir("./train")
categories = []
for filename in filenames:
    category = filename.split('.')[0]
    if category == 'dog':
        categories.append(1)
    else:
        categories.append(0)

df = pd.DataFrame({
    'filename': filenames,
    'category': categories
})

# %%
df.head()
# Out:
#         filename  category
# 0   cat.4853.jpg         0
# 1   cat.1054.jpg         0
# 2   dog.2803.jpg         1
# 3   dog.2775.jpg         1
# 4  dog.11503.jpg         1

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(16, (3,3), activation='relu', input_shape=(150, 150, 3)),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2), 
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'), 
    tf.keras.layers.MaxPooling2D(2,2),
    # Flatten the results to feed into a DNN
    tf.keras.layers.Flatten(), 
    # 512 neuron hidden layer
    tf.keras.layers.Dense(512, activation='relu'), 
    # Only 1 output neuron. It will contain a value from 0-1 where 0 for 1 class ('cats') and 1 for the other ('dogs')
    tf.keras.layers.Dense(1, activation='sigmoid')
])

model.compile(optimizer="adam", loss='binary_crossentropy', metrics=['acc'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 148, 148, 16)      448
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 74, 74, 16)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 72, 72, 32)        4640
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 36, 36, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 34, 34, 64)        18496
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 17, 17, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 18496)             0
# _________________________________________________________________
# dense (Dense)                (None, 512)               9470464
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 513
# =================================================================
# Total params: 9,494,561
# Trainable params: 9,494,561
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

# %%
# not using
earlystop = EarlyStopping(patience=10) #to prevent the overfitting stop the learning rate after 10 epochs

# %%
#reduce the learning rate when then accuracy not increase for 2 steps
#not using
learning_rate_reduction = ReduceLROnPlateau(monitor='val_acc', 
                                            patience=2, 
                                            verbose=1, 
                                            factor=0.5, 
                                            min_lr=0.00001)

# %%
#not using callbacks for now
callbacks = [earlystop, learning_rate_reduction]

# %%
pip install --upgrade scikit-learn
# Out:
# Collecting scikit-learn
#   Using cached https://files.pythonhosted.org/packages/d9/3a/eb8d7bbe28f4787d140bb9df685b7d5bf6115c0e2a969def4027144e98b6/scikit_learn-0.23.1-cp36-cp36m-manylinux1_x86_64.whl
# Collecting scipy>=0.19.1 (from scikit-learn)
#   Using cached https://files.pythonhosted.org/packages/ab/f9/6eeed6d5cd8dd435bbf105d10d778c2d76de1a5838fdbc315a59fb7fad64/scipy-1.5.1-cp36-cp36m-manylinux1_x86_64.whl
# Collecting numpy>=1.13.3 (from scikit-learn)
#   Using cached https://files.pythonhosted.org/packages/00/16/476826a84d545424084499763248abbbdc73d065168efed9aa71cdf2a7dc/numpy-1.19.0-cp36-cp36m-manylinux1_x86_64.whl
# Collecting threadpoolctl>=2.0.0 (from scikit-learn)
#   Using cached https://files.pythonhosted.org/packages/f7/12/ec3f2e203afa394a149911729357aa48affc59c20e2c1c8297a60f33f133/threadpoolctl-2.1.0-py3-none-any.whl
# Collecting joblib>=0.11 (from scikit-learn)
#   Using cached https://files.pythonhosted.org/packages/51/dd/0e015051b4a27ec5a58b02ab774059f3289a94b0906f880a3f9507e74f38/joblib-0.16.0-py3-none-any.whl
# Installing collected packages: numpy, scipy, threadpoolctl, joblib, scikit-learn
# Successfully installed joblib-0.16.0 numpy-1.19.0 scikit-learn-0.23.1 scipy-1.5.1 threadpoolctl-2.1.0
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.model_selection import train_test_split

# %%
total_train = train_df.shape[0]
total_validate = validate_df.shape[0]
batch_size=15

# %%
train_df, validate_df = train_test_split(df, test_size=0.20, random_state=42)
train_df = train_df.reset_index(drop=True)
validate_df = validate_df.reset_index(drop=True)

# %%
df["category"] = df["category"].replace({0: 'cat', 1: 'dog'})

# %%
pip install --upgrade matplotlib
# Out:
# Collecting matplotlib
#   Downloading https://files.pythonhosted.org/packages/e3/a8/bfd8e9ddac55a4a80235f7ccc286e4a08c97e6c4f035f21a27bcab7a51c8/matplotlib-3.2.2-cp36-cp36m-manylinux1_x86_64.whl (12.4MB)
#     100% |████████████████████████████████| 12.4MB 75kB/s eta 0:00:01
# Collecting pyparsing!=2.0.4,!=2.1.2,!=2.1.6,>=2.0.1 (from matplotlib)
#   Downloading https://files.pythonhosted.org/packages/8a/bb/488841f56197b13700afd5658fc279a2025a39e22449b7cf29864669b15d/pyparsing-2.4.7-py2.py3-none-any.whl (67kB)
#     100% |████████████████████████████████| 71kB 44kB/s ta 0:00:01
# Collecting numpy>=1.11 (from matplotlib)
#   Using cached https://files.pythonhosted.org/packages/00/16/476826a84d545424084499763248abbbdc73d065168efed9aa71cdf2a7dc/numpy-1.19.0-cp36-cp36m-manylinux1_x86_64.whl
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading https://files.pythonhosted.org/packages/f7/d2/e07d3ebb2bd7af696440ce7e754c59dd546ffe1bbe732c8ab68b9c834e61/cycler-0.10.0-py2.py3-none-any.whl
# Collecting kiwisolver>=1.0.1 (from matplotlib)
#   Downloading https://files.pythonhosted.org/packages/ae/23/147de658aabbf968324551ea22c0c13a00284c4ef49a77002e91f79657b7/kiwisolver-1.2.0-cp36-cp36m-manylinux1_x86_64.whl (88kB)
#     100% |████████████████████████████████| 92kB 50kB/s ta 0:00:011
# Collecting python-dateutil>=2.1 (from matplotlib)
#   Using cached https://files.pythonhosted.org/packages/d4/70/d60450c3dd48ef87586924207ae8907090de0b306af2bce5d134d78615cb/python_dateutil-2.8.1-py2.py3-none-any.whl
# Collecting six (from cycler>=0.10->matplotlib)
#   Using cached https://files.pythonhosted.org/packages/ee/ff/48bde5c0f013094d729fe4b0316ba2a24774b3ff1c52d924a8a4cb04078a/six-1.15.0-py2.py3-none-any.whl
# Installing collected packages: pyparsing, numpy, six, cycler, kiwisolver, python-dateutil, matplotlib
# Successfully installed cycler-0.10.0 kiwisolver-1.2.0 matplotlib-3.2.2 numpy-1.19.0 pyparsing-2.4.7 python-dateutil-2.8.1 six-1.15.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt

# %%
train_df['category'].value_counts().plot.bar()

# %%
validate_df['category'].value_counts().plot.bar()

# %%
train_datagen = ImageDataGenerator(
    rotation_range=15,
    rescale=1./255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    fill_mode='nearest',
    width_shift_range=0.1,
    height_shift_range=0.1
)

train_generator = train_datagen.flow_from_dataframe(
    train_df, 
    './train', 
    x_col='filename',
    y_col='category',
    class_mode='binary',
    target_size=(150, 150),
    batch_size=15
)
# Out:
# Found 20000 validated image filenames belonging to 2 classes.

# %%
validation_datagen = ImageDataGenerator(rescale=1./255)
validation_generator = validation_datagen.flow_from_dataframe(
    validate_df, 
    "./train", 
    x_col='filename',
    y_col='category',
    class_mode='binary',
    target_size=(150, 150),
    batch_size=batch_size
)
# Out:
# Found 5000 validated image filenames belonging to 2 classes.

# %%
plt.figure(figsize=(12, 12))
for i in range(0, 9):
    plt.subplot(3, 3, i+1)
    for X_batch, Y_batch in train_generator:
        image = X_batch[0]
        plt.imshow(image)
        break
plt.tight_layout()
plt.show()

# %%
history = model.fit_generator(
    train_generator,
    epochs=15,
    validation_data=validation_generator,
    validation_steps=total_validate//batch_size,
    steps_per_epoch=total_train//batch_size,
    callbacks=callbacks
)
# Out:
# Epoch 1/15
# 1333/1333 [==============================] - 468s 351ms/step - loss: 0.6449 - acc: 0.6160 - val_loss: 0.5673 - val_acc: 0.7039
# Epoch 2/15
# 1333/1333 [==============================] - 319s 240ms/step - loss: 0.5449 - acc: 0.7268 - val_loss: 0.5366 - val_acc: 0.7269
# Epoch 3/15
# 1333/1333 [==============================] - 247s 186ms/step - loss: 0.4915 - acc: 0.7615 - val_loss: 0.4478 - val_acc: 0.7860
# Epoch 4/15
# 1333/1333 [==============================] - 278s 209ms/step - loss: 0.4602 - acc: 0.7817 - val_loss: 0.4030 - val_acc: 0.8110
# Epoch 5/15
# 1333/1333 [==============================] - 479s 359ms/step - loss: 0.4299 - acc: 0.7992 - val_loss: 0.4251 - val_acc: 0.8070
# Epoch 6/15
# 1333/1333 [==============================] - 541s 406ms/step - loss: 0.4117 - acc: 0.8140 - val_loss: 0.3590 - val_acc: 0.8414
# Epoch 7/15
# 1333/1333 [==============================] - 520s 390ms/step - loss: 0.3875 - acc: 0.8245 - val_loss: 0.3706 - val_acc: 0.8346
# Epoch 8/15
# 1333/1333 [==============================] - 446s 335ms/step - loss: 0.3726 - acc: 0.8339 - val_loss: 0.3494 - val_acc: 0.8438
# Epoch 9/15
# 1333/1333 [==============================] - 548s 411ms/step - loss: 0.3577 - acc: 0.8420 - val_loss: 0.3582 - val_acc: 0.8456
# Epoch 10/15
# 1333/1333 [==============================] - 456s 342ms/step - loss: 0.3495 - acc: 0.8444 - val_loss: 0.3089 - val_acc: 0.8599
# Epoch 11/15
# 1333/1333 [==============================] - 488s 366ms/step - loss: 0.3375 - acc: 0.8502 - val_loss: 0.3155 - val_acc: 0.8655
# Epoch 12/15
# 1333/1333 [==============================] - 535s 401ms/step - loss: 0.3273 - acc: 0.8566 - val_loss: 0.2929 - val_acc: 0.8749
# Epoch 13/15
# 1333/1333 [==============================] - 444s 333ms/step - loss: 0.3145 - acc: 0.8638 - val_loss: 0.2942 - val_acc: 0.8737
# Epoch 14/15
# 1332/1333 [============================>.] - ETA: 0s - loss: 0.3068 - acc: 0.8661
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 1333/1333 [==============================] - 445s 334ms/step - loss: 0.3071 - acc: 0.8661 - val_loss: 0.3115 - val_acc: 0.8695
# Epoch 15/15
# 1333/1333 [==============================] - 469s 352ms/step - loss: 0.2790 - acc: 0.8783 - val_loss: 0.2536 - val_acc: 0.8909

# %%
acc = history.history['acc']
val_acc = history.history['val_acc']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'bo', label='Training accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
plt.title('Training and validation accuracy')

plt.figure()

plt.plot(epochs, loss, 'bo', label='Training Loss')
plt.plot(epochs, val_loss, 'b', label='Validation Loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %%
#Prepare Testing Data

test_filenames = os.listdir("./test1")
test_df = pd.DataFrame({
    'filename': test_filenames
})
nb_samples = test_df.shape[0]

# %%
#Create Testing Generator

test_gen = ImageDataGenerator(rescale=1./255)
test_generator = test_gen.flow_from_dataframe(
    test_df, 
    "./test1/", 
    x_col='filename',
    y_col=None,
    class_mode=None,
    target_size=(150, 150),
    batch_size=batch_size,
    shuffle=False
)
# Out:
# Found 12500 validated image filenames.

# %%
predict = model.predict_generator(test_generator, steps=np.ceil(nb_samples/batch_size))

# %%
threshold = 0.5
test_df['category'] = np.where(predict > threshold, 1,0)

# %%
test_df['category']
# Out:
# 0        1
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 12495    0
# 12496    1
# 12497    0
# 12498    0
# 12499    0
# Name: category, Length: 12500, dtype: int64

# %%
from tensorflow.keras.preprocessing.image import load_img
sample_test = test_df.sample(n=9).reset_index()
sample_test.head()
plt.figure(figsize=(12, 12))
for index, row in sample_test.iterrows():
    filename = row['filename']
    category = row['category']
    img = load_img("./test1/"+filename, target_size=(256, 256))
    plt.subplot(3, 3, index+1)
    plt.imshow(img)
    plt.xlabel(filename + '(' + "{}".format(category) + ')')
plt.tight_layout()
plt.show()

# %%
# you can check from uploading picture into your folder
import numpy as np
from tensorflow.keras.preprocessing import image

path = './dog.jpg'
img = image.load_img(path, target_size=(150,150))
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)

images = np.vstack([x])
classes = model.predict(images, batch_size=12)
print(classes)
plt.imshow(img)
if classes>0.5:
    print("It is a dog")
else:
    print("It is a cat")
# Out:
# [[1.]]
# It is a dog

# %%
from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score,roc_auc_score,confusion_matrix
